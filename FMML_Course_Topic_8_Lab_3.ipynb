# %% [markdown]
# <a href="https://colab.research.google.com/github/maddalayasaswini/FMML_Lab_Modules/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-01 05:28:25--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   195MB/s    in 0.4s
#
# 2024-04-01 05:28:25 (195 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35478   0708.1527v1  This is to present work on modifying the Aleph...    cs
# 6235   1610.01644v3  Neural network models have a reputation for be...  stat
# 22157  1506.02520v1  The subdifferential of convex functions of the...  stat
# 6172   1608.08052v1  Clustering high-dimensional data often require...  stat
# 8796    1210.3312v1  This paper describes Artex, another algorithm ...    cs
# ...             ...                                                ...   ...
# 6369   1611.08229v1  Dictionary learning is the task of determining...    cs
# 40147  1712.01700v1  Alzheimer's disease is the most common cause o...    cs
# 6821   1706.04918v1  We study the problem of maximizing a monotone ...  stat
# 24389   1311.3318v1  Existing methods in the semantic computer visi...    cs
# 14156  1802.00721v1  Unlike traditional evolutionary algorithms whi...    cs
#
#                                                    title  year  \
# 35478                   A Data-Parallel Version of Aleph  2007
# 6235   Understanding intermediate layers using linear...  2016
# 22157  Convex recovery of tensors using nuclear norm ...  2015
# 6172   Robust Discriminative Clustering with Sparse R...  2016
# 8796                    Artex is AnotheR TEXt summarizer  2012
# ...                                                  ...   ...
# 6369   Fast Orthonormal Sparsifying Transforms Based ...  2016
# 40147  Avaliação da doença de Alzheimer pela análise ...  2017
# 6821   Robust Submodular Maximization: A Non-Uniform ...  2017
# 24389  A Study of Actor and Action Semantic Retention...  2013
# 14156  Improved Runtime Bounds for the Univariate Mar...  2018
#
#                                                 keywords
# 35478  [modifying, evaluates, hypothesised, distribut...
# 6235   [reputation, understand, intermediate, consequ...
# 22157  [subdifferential, functions, optimization, aut...
# 6172   [clustering, dimensional, dimensionality, redu...
# 8796   [describes, algorithm, automatic, summarizatio...
# ...                                                  ...
# 6369   [dictionary, determining, dependent, transform...
# 40147  [alzheimers, difficult, accurately, techniques...
# 6821   [maximizing, submodular, cardinality, constrai...
# 24389  [community, explosion, sophisticated, detectio...
# 14156  [traditional, evolutionary, algorithms, offspr...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35478    [modifying, evaluates, hypothesised, distribut...
# 6235     [reputation, understand, intermediate, consequ...
# 22157    [subdifferential, functions, optimization, aut...
# 6172     [clustering, dimensional, dimensionality, redu...
# 8796     [describes, algorithm, automatic, summarizatio...
#                                ...
# 24842    [reference, statistics, transform, convenient,...
# 38881    [evolution, evolution, theoretical, convergenc...
# 5651     [introduces, probabilistic, dynamically, incor...
# 8990     [authorship, compression, similarity, compress...
# 4050     [combination, compromise, combination, comprom...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8858 words.
# Out of those 4571 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="93bd9cc2-671b-4400-ae7e-4710d055176f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93bd9cc2-671b-4400-ae7e-4710d055176f")) {                    Plotly.newPlot(                        "93bd9cc2-671b-4400-ae7e-4710d055176f",                        [{"x":["evaluation","evaluates","constructed","implementation","libraries","artificially","interface","discusses","modifying","concludes","extension","distributing","distributed","computers","classifier","visualize","heuristics","classifiers","auxiliary","discriminating","demonstrate","potential","inception","understanding","intuition","consequences","understand","generally","reputation","intermediate","subdifferential","extending","automatic","processing","penalization","applications","measurement","functions","statistics","engineering","optimization","situation","discriminative","efficient","algorithms","complexity","dimensionality","previously","clustered","naturally","iterative","separated","variables","dimensions","theoretical","quadratic","improving","equivalent","algorithm","dimensional","proportional","relaxations","performance","probabilistic","regularizers","estimation","reduction","invariant","projection","relaxation","formulations","formulation","dimension","frameworks","clustering","describes","summarization","summaries","generated","interesting","linguistic","campaigns","calculated","necessary","sentences","assembling","conferences","predictions","literature","interpreting","indicates","interpret","explanations","interpretability","appropriate","important","scenarios","principles","interpretable","estimating","importance","satisfies","unexpected","interpretation","prediction","representation","properties","generalized","components","biological","outperform","competitive","classification","different","introduce","established","evaluated","accuracies","organization","signatures","underlying","challenges","empirically","benchmarks","traditional","essentially","suggestion","insensitive","insensitivity","rectified","surprising","differences","foundation","exponentially","criterion","discourages","adaptation","suitability","substantial","inference","decomposition","conventional","interaction","compression","factorization","quantization","recurrent","inappropriate","characterized","techniques","especially","neglected","radically","varieties","technologies","heterogeneous","canonical","homogeneous","prominently","demographics","leveraging","considered","benchmark","combining","communitys","variation","technology","addressing","restrictive","treatment","possibility","supervised","processed","variational","introduction","approximation","modelling","sensitivity","distributions","developed","including","difficult","multitask","leverages","clinically","explosion","electronic","correlations","phenotype","outperforms","available","mortality","baselines","frontiers","healthcare","architecture","detecting","formulate","benchmarking","information"],"y":[245,10,70,114,13,7,28,20,18,9,79,2,108,20,145,7,45,109,21,10,567,146,11,179,12,16,65,67,2,36,0,27,188,278,1,433,29,217,61,53,327,32,108,379,581,242,49,96,15,51,71,7,135,47,161,29,114,66,800,182,15,8,900,166,10,205,104,65,39,22,18,76,61,29,153,76,27,7,179,78,81,5,41,77,57,7,4,88,136,12,22,22,19,14,76,358,96,34,29,74,87,14,8,54,224,359,206,58,96,45,99,111,533,756,343,41,140,30,25,5,124,124,62,99,166,19,3,13,3,9,9,56,16,24,40,2,72,7,44,228,66,104,79,58,29,23,142,8,35,388,128,4,1,3,34,34,22,17,1,5,42,138,217,113,2,60,53,32,3,34,40,202,27,47,30,95,58,33,97,219,268,139,8,31,6,15,18,26,3,269,310,0,56,1,6,224,77,52,17,693],"type":"bar"},{"x":["evaluation","evaluates","constructed","implementation","libraries","artificially","interface"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4571,), (4571, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7891666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>the</span> <span style=''>Latent</span> <span style=''>Look</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discovery</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Style</span> <span style=''>Coherent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Embedding</span> <span style=''>from</span> <span style=''>Fashion</span> <span style=''>Images</span> <br/><br/><span style=''>What</span> <span style=''>defines</span> <span style=''>a</span> <span style=''>visual</span> <span style=''>style</span> <span style=''>Fashion</span> <span style=''>styles</span> <span style=''>emerge</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>organically</span> <span style=''>from</span> <span style=''>how</span> <span style=''>people</span> <span style=''>assemble</span> <span style=''>outfits</span> <span style=''>of</span> <span style=''>clothing</span> <span style=''>making</span> <span style=''>them</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>pin</span> <span style=''>down</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>model</span> <span style=''>Low</span> <span style=''>level</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0.41463414634146345);'>similarity</span> <span style=''>can</span> <span style=''>be</span> <span style=''>too</span> <span style=''>specific</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>stylistically</span> <span style=''>similar</span> <span style=''>images</span> <span style=''>while</span> <span style=''>manually</span> <span style=''>crafted</span> <span style=''>style</span> <span style='background-color:rgba(0, 255, 0, 0.696969696969697);'>categories</span> <span style=''>can</span> <span style=''>be</span> <span style=''>too</span> <span style=''>abstract</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>subtle</span> <span style=''>style</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differences</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>style</span> <span style=''>coherent</span> <span style='background-color:rgba(0, 255, 0, 0.372848948374761);'>representation</span> <span style=''>Our</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>polylingual</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>based</span> <span style=''>on</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0.48148148148148157);'>attributes</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>style</span> <span style=''>factors</span> <span style=''>Given</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collection</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unlabeled</span> <span style=''>fashion</span> <span style=''>images</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>mines</span> <span style=''>for</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>styles</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>summarizes</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Asymptotic</span> <span style=''>Analysis</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Objectives</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Fisher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style=''>in</span> <span style=''>Active</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Obtaining</span> <span style=''>labels</span> <span style=''>can</span> <span style=''>be</span> <span style=''>costly</span> <span style=''>and</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style=''>Active</span> <span style=''>learning</span> <span style=''>allows</span> <span style=''>a</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intelligently</span> <span style=''>query</span> <span style=''>samples</span> <span style=''>to</span> <span style=''>be</span> <span style=''>labeled</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>learning</span> <span style=''>Fisher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>ratio</span> <span style=''>(FIR)</span> <span style=''>has</span> <span style=''>been</span> <span style=''>used</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selecting</span> <span style=''>queries</span> <span style=''>in</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>However</span> <span style=''>little</span> <span style=''>is</span> <span style=''>known</span> <span style=''>about</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>behind</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>FIR</span> <span style=''>for</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>There</span> <span style=''>is</span> <span style=''>a</span> <span style=''>gap</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivation</span> <span style=''>of</span> <span style=''>its</span> <span style=''>usage</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>attempt</span> <span style=''>to</span> <span style=''>fill</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>rigorous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analyzing</span> <span style=''>existing</span> <span style=''>FIR</span> <span style=''>based</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>FIR</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotically</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>an</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>of</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Balanced</span> <span style=''>Mixtures</span> <span style=''>of</span> <span style=''>Discrete</span> <span style='background-color:rgba(255, 0, 0, 0.4393063583815029);'>Distributions</span> <span style=''>with</span> <span style=''>Small</span> <span style=''>Sample</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partitioning</span> <span style=''>a</span> <span style=''>small</span> <span style=''>sample</span> <span style=''>of</span> <span style=''>n</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615385);'>individuals</span> <span style=''>from</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>k</span> <span style=''>product</span> <span style='background-color:rgba(255, 0, 0, 0.4393063583815029);'>distributions</span> <span style=''>over</span> <span style=''>a</span> <span style=''>Boolean</span> <span style=''>cube</span> <span style=''>0</span> <span style=''>1K</span> <span style='background-color:rgba(0, 255, 0, 0.42424242424242425);'>according</span> <span style=''>to</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.4393063583815029);'>distributions</span> <span style=''>Each</span> <span style='background-color:rgba(255, 0, 0, 0.30619469026548674);'>distribution</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>described</span> <span style=''>by</span> <span style=''>a</span> <span style=''>vector</span> <span style=''>of</span> <span style=''>allele</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>frequencies</span> <span style=''>in</span> <span style=''>RK</span> <span style=''>Given</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.4393063583815029);'>distributions</span> <span style=''>we</span> <span style=''>use</span> <span style=''>gamma</span> <span style=''>to</span> <span style=''>denote</span> <span style=''>the</span> <span style=''>average</span> <span style=''>ell</span> <span style=''>22</span> <span style=''>distance</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>frequencies</span> <span style=''>across</span> <span style=''>K</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensions</span> <span style=''>which</span> <span style=''>measures</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.36997885835095146);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3176470588235295);'>divergence</span> <span style=''>between</span> <span style=''>them</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>case</span> <span style=''>assuming</span> <span style=''>that</span> <span style=''>bits</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>across</span> <span style=''>K</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensions</span> <span style=''>This</span> <span style=''>work</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrates</span> <span style=''>that</span> <span style=''>for</span> <span style=''>a</span> <span style=''>balanced</span> <span style=''>input</span> <span style=''>instance</span> <span style=''>for</span> <span style=''>k</span> <span style=''>2</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>graph</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>function</span> <span style=''>returns</span> <span style=''>the</span> <span style=''>correct</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sharp</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style=''>Phase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transitions</span> <span style=''>via</span> <span style=''>Oracle</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computational</span> <span style=''>Model</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tradeoffs</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>accuracy</span> <span style=''>for</span> <span style=''>a</span> <span style=''>general</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>testing</span> <span style=''>problems</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>Based</span> <span style=''>upon</span> <span style=''>an</span> <span style=''>oracle</span> <span style=''>model</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>which</span> <span style=''>captures</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>data</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>a</span> <span style=''>general</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style=''>connects</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>testing</span> <span style=''>risk</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>budget</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>problems</span> <span style=''>This</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>mirrors</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>by</span> <span style=''>Le</span> <span style=''>Cam</span> <span style=''>(1986)</span> <span style=''>and</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achievable</span> <span style=''>given</span> <span style=''>limited</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.07901234567901234)
# 	processing (0.0980599647266314)
# 	knowledge (0.1291005291005291)
# 	segmentation (0.07125220458553792)
# 	information (0.24444444444444444)
# 	experimental (0.14673721340388007)
# 	different (0.26666666666666666)
# 	detection (0.12239858906525573)
# 	convolutional (0.13403880070546736)
# 	recognition (0.13544973544973546)
#
# Some Statistics words are:
# 	distributions (0.1267175572519084)
# 	stochastic (0.1430025445292621)
# 	estimation (0.178117048346056)
# 	theoretical (0.16844783715012723)
# 	statistical (0.1648854961832061)
# 	algorithm (0.3989821882951654)
# 	inference (0.19796437659033078)
# 	distribution (0.18778625954198475)
# 	dimensional (0.20458015267175572)
# 	regression (0.1806615776081425)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="622a547c-cd4d-4a5b-b04b-392920779938" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("622a547c-cd4d-4a5b-b04b-392920779938")) {                    Plotly.newPlot(                        "622a547c-cd4d-4a5b-b04b-392920779938",                        [{"x":["evaluation","evaluates","constructed","implementation","libraries","artificially","interface","discusses","modifying","concludes","extension","distributing","distributed","computers","classifier","visualize","heuristics","classifiers","auxiliary","discriminating","demonstrate","potential","inception","understanding","intuition","consequences","understand","generally","reputation","intermediate","subdifferential","extending","automatic","processing","penalization","applications","measurement","functions","statistics","engineering","optimization","situation","discriminative","efficient","algorithms","complexity","dimensionality","previously","clustered","naturally","iterative","separated","variables","dimensions","theoretical","quadratic","improving","equivalent","algorithm","dimensional","proportional","relaxations","performance","probabilistic","regularizers","estimation","reduction","invariant","projection","relaxation","formulations","formulation","dimension","frameworks","clustering","describes","summarization","summaries","generated","interesting","linguistic","campaigns","calculated","necessary","sentences","assembling","conferences","predictions","literature","interpreting","indicates","interpret","explanations","interpretability","appropriate","important","scenarios","principles","interpretable","estimating","importance","satisfies","unexpected","interpretation","prediction","representation","properties","generalized","components","biological","outperform","competitive","classification","different","introduce","established","evaluated","accuracies","organization","signatures","underlying","challenges","empirically","benchmarks","traditional","essentially","suggestion","insensitive","insensitivity","rectified","surprising","differences","foundation","exponentially","criterion","discourages","adaptation","suitability","substantial","inference","decomposition","conventional","interaction","compression","factorization","quantization","recurrent","inappropriate","characterized","techniques","especially","neglected","radically","varieties","technologies","heterogeneous","canonical","homogeneous","prominently","demographics","leveraging","considered","benchmark","combining","communitys","variation","technology","addressing","restrictive","treatment","possibility","supervised","processed","variational","introduction","approximation","modelling","sensitivity","distributions","developed","including","difficult","multitask","leverages","clinically","explosion","electronic","correlations","phenotype","outperforms","available","mortality","baselines","frontiers","healthcare","architecture","detecting","formulate","benchmarking","information","physiologic","predictive","successful","forecasting","intensive","spreading","implement","researched","influence","advertisers","diffusion","propagated","determining","programming","synthetic","maximization","optimizing","ultimately","strategies","involving","implementing","practical","efficiency","submodular","stochastic","researchers","usability","implementable","advantage","conducting","approaches","parameters","generating","experiments","hierarchical","extensively","surveillance","experimental","component","challenging","surprisingly","pedestrian","convolutional","candidate","proposals","extensive","detection","autonomous","particular","comparison","convolutions","knowledge","architectures","operations","increases","character","im ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	subdifferential
# 	mortality
# 	physiologic
# 	adaboosts
# 	blockmodels
# 	multiplier
# 	uncollapsed
# 	homoscedastic
# 	transferability
# 	circumvents
# 	worsening
# 	autoencoding
# 	nonconjugate
# 	homogeneity
# 	contextualizing
# 	blockmodel
# 	proprietary
# 	projectorg
# 	functioning
# 	ergodicity
# Some words which never appear in Statistics papers:
# 	assembling
# 	conferences
# 	suggestion
# 	neglected
# 	communitys
# 	nonmonotonic
# 	temporarily
# 	intersecting
# 	philosophers
# 	observers
# 	keypoints
# 	measurably
# 	automaton
# 	mutations
# 	indeterminate
# 	determinate
# 	indeterminacies
# 	neutrosophic
# 	authorities
# 	astonishing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.037574800279457e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7366666666666667
